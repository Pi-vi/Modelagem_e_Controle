# %% [markdown]
# # Função de Transferência e de Resposta Impulsiva
#
# Este material serve apenas como um guia para estudos e para as aulas, não substituindo a leitura dos livros indicados e é de uso exclusivo dos alunos do CEFET/RJ campus Angra dos Reis.

# %% [markdown]
# ## Transformada de Laplace

# %% [markdown]
# ![](https://paper-attachments.dropbox.com/s_B7B7589978C0AC41B3D77D7C058BA7A624F97D64CF13504D135CF82FB407646D_1663363398417_image.png)

# %% [markdown]
# → Em essência, a ideia básica de uma transformada é levar o problema desde o espaço físico para um novo espaço abstrato, no qual a solução é obtida de forma conveniente.
#
#
# ![](https://paper-attachments.dropbox.com/s_B7B7589978C0AC41B3D77D7C058BA7A624F97D64CF13504D135CF82FB407646D_1663363735610_image.png)

# %% [markdown]
# → Uma vez resolvendo o problema nesse espaço, utiliza-se uma transformada inversa para retornar para o espaço físico.
#
#
# - Transformada
#
# $X(s) = \mathscr{L}\{x(t)\} = \int_{0}^{\infty} e^{-st}x(t)dt$
#
#
# - Transformada inversa
#
# $x(t) = \mathscr{L}\{X(s)\} = \dfrac{1}{2\pi i}\int_{a-i\infty}^{a+i\infty} e^{st}X(s)ds$
# em que $s = a + ib$

# %% [markdown]
#  Tabela transformadas de Laplace →  https://www.ime.unicamp.br/~msantos/tab-laplace
#
#
# ![](http://media.giphy.com/media/d3mlE7uhX8KFgEmY/giphy.gif)

# %% [markdown]
# Propriedades da transformada de Laplace:
#
# - $\mathscr{L}\{\alpha_1 x_1 + \alpha_2 x_2\} = \alpha_1 X_1 + \alpha_2 X_2$
# - $\mathscr{L}\{\alpha x\} = \alpha X$
# - $\mathscr{L}\{\dot{x}\} = sX - x(0)$
# - $\mathscr{L}\{\ddot{x} \} = s^2 X - sx(0) - x(0)$
#
# Considere o sistema linear invariante no tempo definido pela seguinte equação diferencial:
#
# $a_0 \dfrac{d^{n}y}{dt^{n}} + a_1 \dfrac{d^{n-1}y}{dt^{n-1}} + ... + a_{n-1} \dfrac{dy}{dt} + a_n y = b_{0}\dfrac{d^{m}x}{dt^{m}} + b_{0}\dfrac{d^{m}x}{dt^{m}} + b_{1}\dfrac{d^{m-1}x}{dt^{m-1}}+ b_{m-1}\dfrac{dx}{dt} + b_mx \qquad (n\geq m)$
#
# Onde $y$ é a saída e $x$ é a entrada. A **função de transferência** desse sistema é a relação entre a transformada de Laplace da saída e a transformada de Laplace da entrada, quando todas as condições iniciais são zero, ou:
#
# Função de Transferência = $G(s) = \dfrac{\mathscr{L}[sa\acute{i}da]}{\mathscr{L}[entrada]}$
#
# $G(s) = \dfrac{Y(s)}{X(s)} = \dfrac{b_0 s^m + b_1 s^{m-1} + ... + b_{m-1} s + b_m}{a_0 s^n + a_1s^{n-1} + ... + a_{n-1}s + a_n}$

# %% [markdown]
# A **função de transferência** de um sistema representado por uma equação diferencial linear invariante no tempo é definida como a relação entre a transformada de Laplace da saída (função de resposta) e a transformada de Laplace da entrada (função de excitação), admitindo-se todas as condições iniciais nulas.

# %% [markdown]
# → Uma vez determinada, a função de transferência fornece uma descrição das características dinâmicas do sistema, independentemente de sua descrição física.
#
# → A aplicabilidade do conceito de função de transferência é limitada a sistemas de equações diferenciais lineares invariantes no tempo.

# %% [markdown]
# Para um sistema linear, invariante no tempo, a função de transferência $G(s)$ é:
#
# $G(s) = \dfrac{Y(s)}{X(s)}$
#
# Onde:
# $X(s)$ → é a transformada de Laplace da entrada (função de excitação)
# $Y(s)$ → é a transformada de Laplace da saída do sistema (função de resposta)
#
#
#
# ![](https://paper-attachments.dropbox.com/s_B7B7589978C0AC41B3D77D7C058BA7A624F97D64CF13504D135CF82FB407646D_1663865583403_image.png)

# %% [markdown]
# Por que a Função de Transferência é tão importante?
#
#
# ![](http://media.giphy.com/media/a5viI92PAF89q/giphy.gif)

# %% [markdown]
# ## Função de resposta impulsiva
#
# → Função impulso unitário
# $\delta(t) = \infty \qquad quando \quad t = 0$
# e
# $\delta(t) = 0 \qquad quando \quad t \neq 0$
#
#
# ![](https://paper-attachments.dropbox.com/s_B7B7589978C0AC41B3D77D7C058BA7A624F97D64CF13504D135CF82FB407646D_1663864217207_image.png)
#
# - A resposta a um impulso pode ser entendida como uma condição inicial do sistema, uma vez que sua aplicação ocorre em um instante de tempo determinado e, depois, ela cessa.
#
# → A transformada de Laplace da função impulso unitário é igual a unidade.
#
# A transformada de Laplace da função da saída do sistema é:
#
# $Y(s) = G(s)$
#
# A resposta impulsiva do sistema é então a transformada inversa da função de transferência.
#
# $\mathscr{L}^{-1}[G(s)] = g(t)$
#
#
# ![](https://paper-attachments.dropbox.com/s_B7B7589978C0AC41B3D77D7C058BA7A624F97D64CF13504D135CF82FB407646D_1663870554317_image.png)

# %% [markdown]
# A função de resposta impulsiva $g(t)$ é, portanto, a resposta de um sistema linear invariante no tempo a um impulso unitário de entrara, quando as condições iniciais do sistema são nulas.
#
# É possível obter informações completas sobre as características dinâmicas de um sistema, por meio da excitação por um impulso de entrada e medindo a resposta.

# %% [markdown]
# Um forçamento arbitrário pode ser visto como a combinação de vários impulsos
#
# ![](https://paper-attachments.dropbox.com/s_B7B7589978C0AC41B3D77D7C058BA7A624F97D64CF13504D135CF82FB407646D_1663870752983_image.png)

# %% [markdown]
# ## Transformada de Laplace Utilizando o MATLAB e o Python

# %% [markdown]
# No MATLAB:
#
# ```
# syms t
# f = 3*sin(2*t)
# F = laplace(f)
# pretty(F)
# ```

# %% [markdown]
# No Python:

# %%
from sympy import *

# %%
t,s = symbols('t s')

# %%
f = 3*sin(2*t)
f
# Out:
# 3*sin(2*t)

# %%
F = laplace_transform(f,t,s,noconds=True)
F
# Out:
# 6/(s**2 + 4)

# %% [markdown]
# Outro exemplo:

# %%
a = symbols('a', real=True, positive=True)

# %%
f2 = exp(-a*t)
f2
# Out:
# exp(-a*t)

# %%
F2 = laplace_transform(f2, t, s, noconds=True)
F2
# Out:
# 1/(a + s)

# %% [markdown]
# ## Polos e Zeros de Tranformadas de Laplace

# %% [markdown]
# Geralmente, uma transformada de Laplace pode ser expressa usando o formato:
#
# $F(s) = \dfrac{a(s+z_1)(s+z_2)...(s+z_m)}{(s+p_1)(s+p_2)...(s+p_n)}$
#
# Onde $a$ é uma constante.
#
# Os valores de $s = -z_1$, $s= -z_2$, ..., $s=-z_m$ que fazem com que $F(s) = 0$ são denominados **zeros** da função de transferência.
#
# Os valores de $s = -p_1$, $s = -p_2$, ..., $s=-p_n$ que fazem com que $F(s) = \infty$ são denominados **polos** de $F(s)$.

# %% [markdown]
# Criando a função de transferência:

# %%
from control import *

# %% [markdown]
# OBs.:
# `!pip install control`

# %%
num1 = [10]
den1 = [1,11,24]

# %% [markdown]
# Função de transferência 𝐺1(𝑠)
# :

# %%
G1 = tf(num1,den1)
G1
# Out:
# TransferFunction(array([10]), array([ 1, 11, 24]))

# %%
zero(G1)
# Out:
# array([], dtype=complex128)

# %%
pole(G1)
# Out:
# array([-8.+0.j, -3.+0.j])

# %% [markdown]
# ## Transformada Inversa de Laplace

# %% [markdown]
# A resposta do sistema no domínio de Laplace é expressa por uma razão de polinômios:
#
# $G(s) = \dfrac{Y(s)}{X(s)} = \dfrac{b_0 s^m + b_1 s^{m-1} + ... + b_{m-1} s + b_m}{a_0 s^n + a_1s^{n-1} + ... + a_{n-1}s + a_n}$

# %% [markdown]
# Como o objetivo final é efetuar a transformação inversa, é util utilizar a expansão em frações parciais.
#
# Para isso, é conveniente expressar o denominador D(s) a partir das suas raízes, conhecidas como polos do sistema. Assim:
#
# $X(s) = \dfrac{N(s)}{(s+p_1)(s+p_2)...(s+p_3)}$
#
# $X(s) = \dfrac{C_1}{s+p_1} + \dfrac{C_2}{s+p_2} + ... + \dfrac{C_j}{s+p_n}$
#
# $x(t) = C_1 e^{-p_1 t} + C_2 e ^{-p_2 t} + ... + C_n  e^{p_n t}$

# %% [markdown]
# **Exemplo 1:**
#
# Considere que a resposta de um sistema mecânico no domínio do tempo de Laplace é representado pelo polinômio a seguir. Reescreva o polinômio utilizando expansão em frações parciais.
#
# $X = \dfrac{s+2}{s^3 + 5s^2 + 4s}$

# %% [markdown]
# ---
#
# Expansâo em frações parciais em Python:

# %%
f = (s+2)/(s**3 + 5*s**2 + 4*s)
f
# Out:
# (s + 2)/(s**3 + 5*s**2 + 4*s)

# %%
f.apart()
# Out:
# -1/(6*(s + 4)) - 1/(3*(s + 1)) + 1/(2*s)

# %% [markdown]
# ## Resposta a uma Função Impulso Unitário
#
# A transformada de Laplace da função Impulso Unitário (delta de Dirac) é igual a 1.

# %% [markdown]
# **Exemplo 2:**
#
# Avalie a resposta de um oscilador linear (sistema massa-mola-amortecedor) submetido a um impulso utilizando a transformada de Laplace.
#
# Dados:
# * $m = 2kg$
# * $\zeta = 0.15$
# * $\omega_n = 30$

# %% [markdown]
# ---

# %%
s,t = symbols('s t')

# %%
m = 2
zeta = 0.15
omega_n = 30

# %%
G = (1/m)/(s**2 + 2*zeta*omega_n*s + omega_n**2)
G
# Out:
# 0.5/(s**2 + 9.0*s + 900)

# %%
G.apart(s)
# Out:
# 0.000555555555555556/(0.00111111111111111*s**2 + 0.01*s + 1.0)

# %%
x = inverse_laplace_transform(G,s,t)
x
# Out:
# 1.0*(0.0168573912474725 + 2.16840434497101e-19*I)*exp(-4.5*t)*sin(29.6605798999278*t)*Heaviside(t)

# %%
Heaviside(t) # Função degrau unitário
# Out:
# Heaviside(t)

# %%
plot(Heaviside(t))

# %%
DiracDelta(t)
# Out:
# DiracDelta(t)

# %%
x.subs(Heaviside(t),1)
# Out:
# 1.0*(0.0168573912474725 + 2.16840434497101e-19*I)*exp(-4.5*t)*sin(29.6605798999278*t)

# %%
plot(x,(t,0,2))

# %% [markdown]
# ---

# %%
num = [1/m]
den = [1,2*zeta*omega_n,omega_n**2]

G = tf(num,den)
G
# Out:
# TransferFunction(array([0.5]), array([  1.,   9., 900.]))

# %%
from numpy import linspace

# %%
tn = linspace(0,2,1000)
t1,y1 = impulse_response(G,tn)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(dpi = 300)
plt.plot(t1,y1)
plt.xlabel('tempo[s]')
plt.ylabel('Amplitude')
plt.title('Resposta do sistema massa-mola-amortecedor a uma função impulso')
plt.grid(True)

# %% [markdown]
# Para o oscilador massa-mola-amortecedor, um forçamento do tipo impulso unitário equivale a uma condição inicial $\dot{x} = 1/m$.

# %%
t1,y2 = initial_response(G,tn,[1/m,0])

# %%
plt.figure(dpi = 300)
plt.plot(t1,y2)
plt.xlabel('tempo[s]')
plt.ylabel('Amplitude')
plt.title(r'Resposta do sistema massa-mola-amortecedor a uma condição inicial $\dot{x} = 1/m$')
plt.grid(True)

# %% [markdown]
# ---

# %%
T = symbols('T',positive = True, real = True)

# %%
C1 = 1/(T*s + 1)*(1/s)
C1
# Out:
# 1/(s*(T*s + 1))

# %%
c1 = inverse_laplace_transform(C1, s, t)
c1
# Out:
# Heaviside(t) - exp(-t/T)*Heaviside(t)

# %%
c1.subs(Heaviside(t),1)
# Out:
# 1 - exp(-t/T)

# %%
Y = (2*s + 9)/(s**2 + 6*s + 25)
Y
# Out:
# (2*s + 9)/(s**2 + 6*s + 25)

# %%
y = inverse_laplace_transform(Y,s,t)
y
# Out:
# (3*sin(4*t) + 8*cos(4*t))*exp(-3*t)*Heaviside(t)/4

# %%
y.subs(Heaviside(t),1)
# Out:
# (3*sin(4*t) + 8*cos(4*t))*exp(-3*t)/4

# %% [markdown]
# ---

# %% [markdown]
# Os passos básicos para empregar o método da transformada de Laplace na obtenção da solução da equação do modelo matemático do sistema no domínio do tempo são:
#
# 1. Determine a transformada de Laplace de todos os termos da equação do sistema e inclua as condições iniciais. Esse passo irá converter uma EDO em uma equação algébrica na variável de Laplace.
# 2. Resolva a expressão algébrica do passo 1 para a trasnformada de Laplace da saída Y(s).
# 3. Determine a transformada inversa de Laplace Y(s) para obter a resposta no tempo de saída y(t).}

# %% [markdown]
# **Exemplo 3:**
#
# Dada a seguinte equação (modelo matemático):
#
# $2\ddot{y} + 10\dot{y} + 12y = u(t)$
#
# com:
#
# $y(0) = -1$
#
# $\dot{y}(0) = 0.5$
#
# determine a resposta dinâmica $y(t)$ se a entrada é uma função degrau $u(t) = 4$ para $ t> 0$

# %% [markdown]
# **Exemplo 4:**
#
# A figura a seguir mostra um sistema mecânico com um único disco, no qual um motor fornece o torque $T_{ent}(t)$ diretamente à inércia do rotor $J$.Obtenha a resposta da velocidade angular desse sistema mecânico se o rotor inicialmente está girando com $\omega(0) = 120rad/s$ (1146rpm) e o torque de entrada é uma função degrau de amplitude 15N.m (aplicada em $t > 0$). O momento de inércia $J = 0,4kgm²$ e o coeficiente de atrito viscoso é $b = 0,06N.m.s/rad$.

# %% [markdown]
# ![image.png](attachment:image.png)
